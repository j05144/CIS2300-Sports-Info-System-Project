# %% [markdown]
# PANDAS

# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# !pip install Wikipedia-API

# %%
import pandas as pd
import matplotlib.pyplot as plt
import wikipediaapi as wk
# %matplotlib inline

df=pd.read_csv("sports.csv")
print(df)
print("-----------------------------------------------")
print(df.T)
print("-----------------------------------------------")
print(df.describe())
print("-----------------------------------------------")
print(df.columns)
print("-----------------------------------------------")
print(df.info())
# Out:
#          SPORT  FRA  GER  USA  CHI  RUS  JAP
# 0   VOLLEYBALL    1    4    2    5    4    3
# 1       SOCCER    4    1    1    3    2    2
# 2   BASKETBALL    2    3    4    1    1    4
# 3     MARATHON    5    1    3    2    3    5
# 4       TENNIS    2    3    5    2    3    1
# 5        RUGBY    3    2    3    1    3    4
# 6          BOX    6    3    3    3    2    3
# 7         GOLF    1    3    3    3    4    3
# 8      CRICKET    4    3    3    3    4    1
# 9           F1    3    5    3    2    1    3
# 10   PING PONG    6    1    3    4    3    3
# 11  GYMNASTICS    7    5    4    5    1    1
# -----------------------------------------------
#                0       1           2         3       4      5    6     7   \
# SPORT  VOLLEYBALL  SOCCER  BASKETBALL  MARATHON  TENNIS  RUGBY  BOX  GOLF
# FRA             1       4           2         5       2      3    6     1
# GER             4       1           3         1       3      2    3     3
# ...

# %%
df=pd.read_csv("sports.csv")
print(df[df.index==2])

print(df[1:4])

print("----------------")
print(df.loc[1:4,["FRA","GER","JAP"]])
# Out:
#         SPORT  FRA  GER  USA  CHI  RUS  JAP
# 2  BASKETBALL    2    3    4    1    1    4
#         SPORT  FRA  GER  USA  CHI  RUS  JAP
# 1      SOCCER    4    1    1    3    2    2
# 2  BASKETBALL    2    3    4    1    1    4
# 3    MARATHON    5    1    3    2    3    5
# ----------------
#    FRA  GER  JAP
# 1    4    1    2
# 2    2    3    4
# 3    5    1    5
# 4    2    3    1

# %%
df=pd.read_csv("sports.csv")
df=df.set_index("SPORT")

sports=input("Please enter sports (# as seperator)")
countries=input("Please enter countries (# as seperator)")
sports=sports.split("#")
countries=countries.split("#")
print(df.loc[sports,countries])
# Out:
# Please enter sports (# as seperator) F1#TENNIS#SOCCER
# Please enter countries (# as seperator) FRA#JAP#USA
#         FRA  JAP  USA
# SPORT
# F1        3    3    3
# TENNIS    2    1    5
# SOCCER    4    2    1

# %%
df=pd.read_csv("sports.csv")
df=df.set_index("SPORT")
print(df)

df.loc["KARATE"]=[7,5,4,1,1,4]
df["AUS"]=[1,2,3,5,6,1,2,3,"none",5,6,4,3]

print("--------------------------------------")
print(df)

df.loc[["TENNIS","SOCCER","KARATE"],["FRA","GER","USA"]].plot(kind="bar")
plt.show() #you may need this line
# Out:
#             FRA  GER  USA  CHI  RUS  JAP
# SPORT
# VOLLEYBALL    1    4    2    5    4    3
# SOCCER        4    1    1    3    2    2
# BASKETBALL    2    3    4    1    1    4
# MARATHON      5    1    3    2    3    5
# TENNIS        2    3    5    2    3    1
# RUGBY         3    2    3    1    3    4
# BOX           6    3    3    3    2    3
# GOLF          1    3    3    3    4    3
# CRICKET       4    3    3    3    4    1
# F1            3    5    3    2    1    3
# PING PONG     6    1    3    4    3    3
# GYMNASTICS    7    5    4    5    1    1
# --------------------------------------
#             FRA  GER  USA  CHI  RUS  JAP   AUS
# SPORT
# VOLLEYBALL    1    4    2    5    4    3     1
# SOCCER        4    1    1    3    2    2     2
# BASKETBALL    2    3    4    1    1    4     3
# MARATHON      5    1    3    2    3    5     5
# TENNIS        2    3    5    2    3    1     6
# RUGBY         3    2    3    1    3    4     1
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import wikipediaapi as wk
# %matplotlib inline

df=pd.read_csv("sports.csv")
df=df.set_index("SPORT")
scores=[]

print("************************************************")
# PRINT ALL DATA
print(df.plot(kind="bar"))
plt.show()


print("************************************************")
#PRINT SELECTED DATA
sports=input("PLEASE INPUT SPORTS (SEPERATED BY &)")
countries=input("PLEASE INPUT COUNTRIES (SEPERATED BY &)")
#CHANGE EVERYTHING TO UPPERCASE
sports=sports.upper()
countries=countries.upper()
#CONVERT TO A LIST
sports=sports.split("&")
countries=countries.split("&")
df.loc[sports,countries]
df.loc[sports,countries].plot(kind="bar")
plt.show()


#print("************************************************")
#READ NEW SPORT
#sport=input("PLEASE ENTER NEW SPORT: ")
#sport=sport.upper()
#READ SCORES
#GET THE NUMBER OF COUNTIRES (use Len of the columns)
#for i in range(len(df.columns)):
    #GET A VALUE FOR EACH COUNTRY
    #score=int(input("PLEASE ENTER THE SCORE FOR "+df.columns[i]+": "))
    #ADD TO LIST
    #scores.append(score)
#ADD THE NEW RECORD
#df.loc[sport]=scores
#print("************************************************")
#print(df)

#DROP A SPORT
#sport=input("PLEASE ENTER SPORT TO DROP: ")
#df=df.drop(sport)
#print("************************************************")
#print(df)

country=input("PLEASE ENTER A COUNTRY OR SPORT: ")
wiki = wk.Wikipedia('Test123 (test123@example.com)', 'en')
page = wiki.page(country)
print (page.exists())
print (page.summary)
# Out:
# ************************************************
# Axes(0.125,0.11;0.775x0.77)
# ************************************************
# PLEASE INPUT SPORTS (SEPERATED BY &) box
# PLEASE INPUT COUNTRIES (SEPERATED BY &) fra
# PLEASE ENTER A COUNTRY OR SPORT:  FRANCE
# True
# ...

# %%
user_input=""
while user_input!="X":
    if user_input=="1":
        print("EATTTT")
    elif user_input=="2":
        print("EXPENSIVE")
    elif user_input=="3":
        print("OKKKK")
    elif user_input=="4":
        print("zzzzzzz")
    user_input=input("PLEASE SELECT OPTION\n1-EAT LUNCH\n2-GO SHOPPING\n3-STUDY FOR FINAL\n4-NAP\nX-EXIT")
# Out:
# PLEASE SELECT OPTION
# 1-EAT LUNCH
# 2-GO SHOPPING
# 3-STUDY FOR FINAL
# 4-NAP
# X-EXIT 2
# EXPENSIVE
# PLEASE SELECT OPTION
# 1-EAT LUNCH
# 2-GO SHOPPING
# 3-STUDY FOR FINAL
# 4-NAP
# X-EXIT 3
# OKKKK
# PLEASE SELECT OPTION
# 1-EAT LUNCH
# 2-GO SHOPPING
# 3-STUDY FOR FINAL
# 4-NAP
# X-EXIT 4
# zzzzzzz
# PLEASE SELECT OPTION
# 1-EAT LUNCH
# 2-GO SHOPPING
# 3-STUDY FOR FINAL
# 4-NAP
# X-EXIT 6
# PLEASE SELECT OPTION
# 1-EAT LUNCH
# 2-GO SHOPPING
# 3-STUDY FOR FINAL
# 4-NAP
# X-EXIT X

# %%
import wikipediaapi as wk
wiki = wk.Wikipedia('Test123 (test123@example.com)', 'en')
search_pattern=input("Please enter sport or country")
page = wiki.page(search_pattern)
print (page.exists())
print (page.summary[0:300])
# Out:
# Please enter sport or country tennis
# True
# Tennis is a racket sport that is played either individually against a single opponent (singles) or between two teams of two players each (doubles). Each player uses a tennis racket strung with a cord to strike a hollow rubber ball covered with felt over or around a net and into the opponent's court.

# %%
# !pip install pynytimes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import wikipediaapi as wk
# %matplotlib inline

# load file
df = pd.read_csv("sports.csv")
df = df.set_index("SPORT")

# Wikipedia object (required user agent)
wiki = wk.Wikipedia(
    language="en",
    user_agent="CIS2300-Project (student@example.com)"
)

print("CIS2300 Sports Project")

# menu variable
op = ""

while op != "X":
    print("\n--- MAIN MENU ---")
    print("A - Show all data")
    print("S - Show selected sports/countries")
    print("N - Add a new sport")
    print("D - Delete a sport")
    print("W - Save changes")
    print("I - Wikipedia information")
    print("X - Exit")

    op = input("Choose an option: ").upper()

    # A - All data
    if op == "A":
        print("\n--- FULL DATA ---")
        print(df)
        g = input("Show chart? (y/n): ").upper()
        if g == "Y":
            df.plot(kind="bar")
            plt.show()

    # S - Selected
    elif op == "S":
        countries = input("Enter countries (comma): ").upper().split(",")
        countries = [c.strip() for c in countries]

        sports = input("Enter sports (comma): ").upper().split(",")
        sports = [s.strip() for s in sports]

        try:
            selected = df.loc[sports, countries]
            print("\n--- SELECTED DATA ---")
            print(selected)

            g = input("Show chart? (y/n): ").upper()
            if g == "Y":
                selected.plot(kind="bar")
                plt.show()
        except:
            print("Invalid sport or country entered.")

    # N - New sport
    elif op == "N":
        new_sport = input("Enter new sport name: ").upper()
        scores = []

        for c in df.columns:
            value = int(input(f"Enter score for {c}: "))
            scores.append(value)

        df.loc[new_sport] = scores
        print("Sport is successfully added.")

    # D - Delete sport
    elif op == "D":
        remove_sport = input("Enter sport to delete: ").upper()
        if remove_sport in df.index:
            df = df.drop(remove_sport)
            print("Sport successfully deleted.")
        else:
            print("Sport not found.")

    # W - Save to CSV
    elif op == "W":
        df.to_csv("sports.csv")
        print("Saved to sports.csv.")

    # I - Wikipedia information
    elif op == "I":
        term = input("Search term: ")
        page = wiki.page(term)
        if page.exists():
            print("\n--- INFORMATION ---")
            print(page.summary[:600])
        else:
            print("No information found.")

    # X - Exit
    elif op == "X":
        print("Goodnight!")

    else:
        print("Uh oh! Try again.")
# Out:
# CIS2300 Sports Project
#
# --- MAIN MENU ---
# A - Show all data
# S - Show selected sports/countries
# N - Add a new sport
# D - Delete a sport
# W - Save changes
# I - Wikipedia information
# X - Exit
# Choose an option:  A
# --- FULL DATA ---
#             FRA  GER  USA  CHI  RUS  JAP
# SPORT
# VOLLEYBALL    1    4    2    5    4    3
# SOCCER        4    1    1    3    2    2
# BASKETBALL    2    3    4    1    1    4
# MARATHON      5    1    3    2    3    5
# TENNIS        2    3    5    2    3    1
# RUGBY         3    2    3    1    3    4
# BOX           6    3    3    3    2    3
# GOLF          1    3    3    3    4    3
# CRICKET       4    3    3    3    4    1
# F1            3    5    3    2    1    3
# PING PONG     6    1    3    4    3    3
# GYMNASTICS    7    5    4    5    1    1
# Show chart? (y/n):  y
# --- MAIN MENU ---
# A - Show all data
# S - Show selected sports/countries
# N - Add a new sport
# D - Delete a sport
# W - Save changes
# ...
